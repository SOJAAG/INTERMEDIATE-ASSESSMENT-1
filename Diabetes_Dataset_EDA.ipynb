# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Univariate Analysis

# %%
data=pd.read_csv('diabetes_model.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %% [markdown]
# Q1.plot histogram for the above data

# %%
plt.hist(data["Insulin"],color="blue",rwidth=0.8,density=True)
plt.title("Histogram of Diabetes Dataset")
plt.xlabel("Insulin")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# Q2.plot Boxplot of Glucose from Diabetes dataset

# %%
import seaborn as sns

# %%
np.mean(data["Glucose"])
# Out:
# np.float64(121.5)

# %%
np.std(data["Glucose"])
# Out:
# 32.24962439495436

# %%
sns.boxplot(data["Glucose"])


plt.title("Box Plot of Dataset ")
plt.show()

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# Q3.Scatter plot of Blood Pressure vs BMI

# %%
plt.figure(figsize=(5,3))

plt.scatter(data["BloodPressure"],data["BMI"], c="b", marker="*")

plt.title("Blood Pressure vs BMI")
plt.xlabel("BloodPressure")
plt.ylabel("BMI")
plt.show()

# %% [markdown]
# Q4.Correlation matrix for Diabetes

# %%
correlation_matrix = data.corr()

print("Correlation Matrix:\n",correlation_matrix)
# Out:
# Correlation Matrix:
#                            Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.137245       0.165089      -0.101968
# Glucose                      0.137245  1.000000       0.151446       0.073133
# BloodPressure                0.165089  0.151446       1.000000       0.209564
# SkinThickness               -0.101968  0.073133       0.209564       1.000000
# Insulin                     -0.083955  0.320291       0.083704       0.433628
# BMI                         -0.005699  0.237282       0.283813       0.379994
# DiabetesPedigreeFunction    -0.039171  0.134167       0.025739       0.180571
# Age                          0.552744  0.251873       0.227663      -0.111832
# Outcome                      0.201069  0.478688       0.056902       0.086276
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.083955 -0.005699                 -0.039171
# ...

# %% [markdown]
# Multivariate Analysis

# %% [markdown]
# Q5.Pair plot of Diabetes dataset

# %%
sns.pairplot(data,hue="Outcome", x_vars=["Glucose"])
plt.show()

# %% [markdown]
# Q6. 3D Plot for the Dataset Diabetes

# %%
fig=plt.figure()
ax=fig.add_subplot(111,projection="3d")
ax.scatter(data["Glucose"],data["BloodPressure"],data["BMI"],c=data['Outcome'],cmap='viridis')
ax.set_xlabel("Glucose")
ax.set_ylabel("BloodPressure")
ax.set_zlabel("BMI")
plt.title("3D Plot of Diabetes Dataset")
plt.show()
